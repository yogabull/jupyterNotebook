# %% [markdown]
# # Sample Headline
# *Note: This tesxt will be italicized.*
#
# ## Another Headline (H2)
# This is a normal paragraph.
# This cell was converted to a markdown cell.
#
# ### What this notebook shows
# Basic formatting of *italics* and **bold** or __bold__ is supported. This *can be **nested** like* so.
#
# 1. list item one
# 2. list item two
# 3. list item three

# %% [markdown]
# ## notebooks have something called magics
#
# They start with % or %% (one or two percent signs).

# %%
number = input('enter number: ')
print(number)

# %%
pip list

# %% [markdown]
# ## notebooks have something called magics
#
# They start with % or %% (one or two percent signs).
#
# **Line Magics -** % means commands arguements come from this same line.
# **Celle Magics -** %% means that this entire cell's arguements will come from this same cell.
#
# One magic command is: lsmagic

# %%
lsmagic

# %%
# %pwd

# %%
# %ls

# %%
# %ls -la

# %%
# %matplotlib inline

# %%
"""
Simple demo of scatter plot.
"""
import numpy as np
import matplotlib.pyplot as plt
import random

N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2 # 0 to 15 point radiuses

plt.scatter(x,y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
print("hello world")
# Out:
# hello world

# %%
# %pwd
# Out:
# '/Users/dunnjt/Code/jupyter'

# %%
# %ls
# Out:
# Testing Jupyter.ipynb

# %% [markdown]
# ## just ran an ls above this bad boy.
